# %% [markdown]
# # ITAI 1378 Computer Vision — First Notebook

# %%
course = "ITAI 1378 Computer Vision"
goal = "Get an A"
print(f"{course}: mission = {goal} 🥊")
# Out:
# ITAI 1378 Computer Vision: mission = Get an A 🥊
